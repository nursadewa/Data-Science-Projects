# %% [markdown]
# IMPORT LIBRARY

# %%
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib inline
import seaborn as sns

# %% [markdown]
# IMPORT FILE CSV

# %%
df = pd.read_csv('/content/drive/MyDrive/Gcolab/ds_salaries.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
# # 1 Exploratory Data Analysis

# %% [markdown]
# ## 1.1 Check Null Values

# %%
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
# ## 1.2 Check Duplicate Data

# %%
df.shape
# Out:
# (3755, 11)

# %%
df[df.duplicated()]
# Out:
#       work_year experience_level employment_type           job_title  salary  \
# 115        2023               SE              FT      Data Scientist  150000
# 123        2023               SE              FT  Analytics Engineer  289800
# 153        2023               MI              FT       Data Engineer  100000
# 154        2023               MI              FT       Data Engineer   70000
# 160        2023               SE              FT       Data Engineer  115000
# ...         ...              ...             ...                 ...     ...
# 3439       2022               MI              FT      Data Scientist   78000
# 3440       2022               SE              FT       Data Engineer  135000
# 3441       2022               SE              FT       Data Engineer  115000
# 3586       2021               MI              FT       Data Engineer  200000
# 3709       2021               MI              FT      Data Scientist   76760
#
# ...

# %%
df[df.duplicated()].shape
# Out:
# (1171, 11)

# %% [markdown]
# ### Copy Data

# %%
df_c = df.copy()

# %%
df_c.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
df_c.shape
# Out:
# (3755, 11)

# %% [markdown]
# ### Delete Duplicate Data

# %%
df_c = df_c.drop_duplicates()

# %%
df_c.shape
# Out:
# (2584, 11)

# %% [markdown]
# ## 1.3 Check Unique Values in Each Column

# %% [markdown]
# ### Check Data Type

# %%
df_c.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# ### Check Data stats

# %%
df_c.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  2584.000000  2.584000e+03    2584.000000   2584.000000
# mean   2022.301084  2.103653e+05  133409.280186     50.483746
# std       0.749179  8.080375e+05   67136.837329     48.163707
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  9.000000e+04   84975.000000      0.000000
# 50%    2022.000000  1.346300e+05  130000.000000     50.000000
# 75%    2023.000000  1.825625e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %% [markdown]
# ### Check Columns

# %%
df_c.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ### Unique Values Check

# %%
for column in df_c.columns:
  if df_c[column].dtypes == object:
    num_distinct = df_c[column].nunique() #ada berapa unique value (sum)
    distinct_val = df_c[column].unique() #unique valuenya apa aja

    print(f"{column} : {num_distinct} --> {distinct_val} \n")
# Out:
# experience_level : 4 --> ['SE' 'MI' 'EN' 'EX']
#
# employment_type : 4 --> ['FT' 'CT' 'FL' 'PT']
#
# job_title : 93 --> ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
# ...

# %% [markdown]
# ## 1.4 Rename Value for Better Understanding

# %%
# ['SE' 'MI' 'EN' 'EX']
# ['FT' 'CT' 'FL' 'PT']
df_c['experience_level'] = df_c['experience_level'].replace({
    'SE' : 'Senior',
    'EN' : 'Entry Level',
    'EX' : 'Executive Level',
    'MI' : 'Mid/Intermediate Level'
})

df_c['employment_type'] = df_c['employment_type'].replace({
    'FT':'Senior',
    'PT' : 'Entry Level',
    'FL' : 'Freelance',
    'CT' : 'Contractor'
})

df_c['remote_ration'] = df_c['remote_ratio'].replace({
    0 :'Full Time',
    50 : 'Part Time',
    100 : 'Remote'
})

# %%
df_c
# Out:
#       work_year        experience_level employment_type  \
# 0          2023                  Senior          Senior
# 1          2023  Mid/Intermediate Level      Contractor
# 2          2023  Mid/Intermediate Level      Contractor
# 3          2023                  Senior          Senior
# 4          2023                  Senior          Senior
# ...         ...                     ...             ...
# 3750       2020                  Senior          Senior
# 3751       2021  Mid/Intermediate Level          Senior
# 3752       2020             Entry Level          Senior
# 3753       2020             Entry Level      Contractor
# 3754       2021                  Senior          Senior
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 0     Principal Data Scientist    80000             EUR          85847
# 1                  ML Engineer    30000             USD          30000
# 2                  ML Engineer    25500             USD          25500
# ...

# %% [markdown]
# ## 1.5 Group the Job title

# %% [markdown]
# ### Check Job Title

# %%
print(df_c['job_title'].nunique())
print(df_c['job_title'].unique())
# Out:
# 93
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
#  'Autonomous Vehicle Technician' 'Applied Machine Learning Scientist'
#  'Lead Data Scientist' 'Cloud Database Engineer' 'Financial Data Analyst'
# ...

# %% [markdown]
# ### Grouping Function

# %%
def assign_broader_category(job_title):
  data_engineering = ["Data Engineer", "Data Analyst", "Analytics Engineer", "BI Data Analyst", "Business Data Analyst", "BI Developer", "BI Analyst", "Business Intelligence Engineer", "BI Data Engineer", "Power BI Developer"]
  data_scientist = ["Data Scientist", "Applied Scientist", "Research Scientist", "3D Computer Vision Researcher", "Deep Learning Researcher", "AI/Computer Vision Engineer"]
  machine_learning = ["Machine Learning Engineer", "ML Engineer", "Lead Machine Learning Engineer", "Principal Machine Learning Engineer"]
  data_architecture = ["Data Architect", "Big Data Architect", "Cloud Data Architect", "Principal Data Architect"]
  management = ["Data Science Manager", "Director of Data Science", "Head of Data Science", "Data Scientist Lead", "Head of Machine Learning", "Manager Data Management", "Data Analytics Manager"]

  if job_title in data_engineering:
    return 'Data Engineering'
  elif job_title in data_scientist:
    return 'Data Scientist'
  elif job_title in machine_learning:
    return 'Machine Learning'
  elif job_title in data_architecture:
    return 'Data Architecture'
  elif job_title in management:
    return 'Management'
  else:
    return 'Other'

# %%
df_c['job_category'] = df_c['job_title'].apply(assign_broader_category)

# %%
print(df_c['job_category'].nunique())
print(df_c['job_category'].unique())
# Out:
# 6
# ['Other' 'Machine Learning' 'Data Scientist' 'Data Engineering'
#  'Data Architecture' 'Management']

# %% [markdown]
# ## 1.6 Adjust Salary to Present Values

# %%
df_c.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size', 'remote_ration',
#        'job_category'],
#       dtype='object')

# %% [markdown]
# ### Inflation Rate

# %%
# Inflation rates
us_inflation_rates = {2019: 0.0181,
                      2020: 0.0123,
                      2021: 0.0470,
                      2022: 0.065}
global_inflation_rates = {2019: 0.0219,
                          2020: 0.0192,
                          2021: 0.0350,
                          2022: 0.088}

def adjust_salary(x):
  year = x['work_year']
  ori_salary = x['salary_in_usd']
  currency = x['salary_currency']

  # Kondisi pertama(Jika tahun 2023 maka tidak terkena inflasi)
  if year == 2023:
    return ori_salary
  else:
    adjust_salary = ori_salary
    for y in range(year, 2023): #Loop tahun sampai tahun 2022 / stop sebelum 2023
      # Kondisi kedua (jika currency adalah USD maka digunakan us_inflation_rate, selain USD gunakan global
      if currency == 'USD':
        inflation_rate = us_inflation_rates[y]
      else:
        inflation_rate = global_inflation_rates[y]

      adjust_salary = adjust_salary * (1 + inflation_rate)
    return adjust_salary

# %%
df_c['adjusted_salary'] = df_c.apply(adjust_salary, axis=1)

# %%
df_c.tail()
# Out:
#       work_year        experience_level employment_type  \
# 3750       2020                  Senior          Senior
# 3751       2021  Mid/Intermediate Level          Senior
# 3752       2020             Entry Level          Senior
# 3753       2020             Entry Level      Contractor
# 3754       2021                  Senior          Senior
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 3750            Data Scientist   412000             USD         412000
# 3751  Principal Data Scientist   151000             USD         151000
# 3752            Data Scientist   105000             USD         105000
# 3753     Business Data Analyst   100000             USD         100000
# 3754      Data Science Manager  7000000             INR          94665
#
#      employee_residence  remote_ratio company_location company_size  \
# 3750                 US           100               US            L
# ...

# %% [markdown]
# # SOAL No.1
# Show the median adjusted data scientist salary, for each experience level

# %% [markdown]
# ## JAWABAN No.1

# %%
df_c.groupby(['experience_level']).agg({'salary' : 'median'})
# Out:
#                           salary
# experience_level
# Entry Level              74770.0
# Executive Level         195150.0
# Mid/Intermediate Level  100000.0
# Senior                  150000.0

# %% [markdown]
# # SOAL No. 2
# Show the number of records for each company_location, sorted descending

# %% [markdown]
# ## JAWABAN No.2

# %%
df_c.groupby('company_location').size().reset_index(name='number of records').sort_values(by='number of records', ascending=False)
# Out:
#    company_location  number of records
# 70               US               1929
# 28               GB                155
# 12               CA                 83
# 38               IN                 57
# 20               DE                 55
# ..              ...                ...
# 24               EG                  1
# 50               MT                  1
# 49               MK                  1
# 48               MD                  1
# 71               VN                  1
#
# [72 rows x 2 columns]

# %% [markdown]
# # SOAL No.3
# From this data, show the median adjusted salary of employee who works for company located in Indonesia, do you think that value represents the salary in Indonesia? why? why not?

# %% [markdown]
# ## JAWABAN No.3

# %%
# Filter employees yang bekerja di Indonesia (ID)
# id_employees = df_c[df_c['company_location'] == 'ID']

# Hitung nilai median dari Adjusted Salary
# id_employees['adjusted_salary'].median()

# %%
#  Filter employees yang bekerja di Indonesia (ID)
indonesia_employees = df_c[df_c['company_location'] == 'ID']

# Hitung nilai median dari kolom adjusted_salary
median_salary = indonesia_employees['adjusted_salary'].median()

# Buat DataFrame untuk menampilkannya dalam bentuk tabel
pd.DataFrame({'Median Adjusted Salary': [median_salary]}, index=['Indonesia (ID)'])
# Out:
#                 Median Adjusted Salary
# Indonesia (ID)               37045.804

# %% [markdown]
# ## yang bekerja di company yang berada di Indonesia ada 2 orang

# %%
# Filter employees who work in Indonesia (ID)
id_employees = df_c[df_c['company_location'] == 'ID']

# Calculate the median adjusted salary
id_employees['adjusted_salary']
# Out:
# 3061    58116.608
# 3139    15975.000
# Name: adjusted_salary, dtype: float64

# %% [markdown]
# **Kesimpulan** <br>
# ................

# %% [markdown]
# Untuk menyimpulkan keterwakilan nilai salary dari perusahaan yang berlokasi di indonesia dari tahun 2020 sd tahun 2023. Maka harus melihat dari nilai sampling data dan jumlah penduduk pekerja di Indonesia.
#
# **Sumber Referensi:**
# 1. Berapa nilai sampling yang harus dilihat supaya nilai nya akurat:
#       https://www.checkmarket.com/blog/how-to-estimate-your-population-and-survey-sample-size/#
# 2. Hitung calculator sample size dengan populasi:
#       https://www.checkmarket.com/sample-size-calculator/#
#
# 3. Informasi dari BPS dan Kemnaker, jumlah pekerja di Indonesia pada tahun 2021 sd tahun 2023:
# https://satudata.kemnaker.go.id/infografik/59#:~:text=Berdasarkan%20kegiatannya%2C%20angkatan%20kerja%20meliputi,persen%20pada%20periode%202021%20s.d.

# %% [markdown]
# Jadi, dari hasil pengolahan data sebelumnya yang didapat, nilai data salary tersebut belum bisa mewakili nilai salary pada umumnya untuk lokasi company di Indonesia.
#
# Data tersebut belum lengkap karena hanya menyebut negara, tanpa ada keterangan lokasi dimana perusahaan tersebut berada. Apakah ada di kota Besar ? di Provinsi tertentu ? atau bidang industri perusahaannya.
#
# Akan tetapi jika ingin mendapatkan hasil yang sesuai, bisa ditambahkan jumlah data employee/pekerja yang berlokasi di indonesia.
